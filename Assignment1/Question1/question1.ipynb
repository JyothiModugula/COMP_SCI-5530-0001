# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('sample.csv')
df.head()
# Out:
#    Height (inches)  Weight (lbs)  Age  Grip strength Frailty
# 0             65.8           112   30             30       N
# 1             71.5           136   19             31       N
# 2             69.4           153   45             29       N
# 3             68.2           142   22             28       Y
# 4             67.8           144   29             24       Y

# %%
fig1 = plt.scatter(df["Grip strength"],df["Age"])
plt.show()

# %%
fig2 = plt.scatter(df["Height (inches)"],df["Weight (lbs)"])
plt.show()

# %%
fig3 = plt.scatter(df["Frailty"],df["Age"])
plt.show()

# %%
fig4 = plt.scatter(df["Frailty"],df["Grip strength"])
plt.show()

# %%
fig5 = plt.scatter(df["Weight (lbs)"],df["Grip strength"])
plt.show()

# %%
fig6 = plt.scatter(df["Height (inches)"],df["Age"])
plt.show()
